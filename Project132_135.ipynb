# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinithiBala2021/INTERPRETING-RESULTS/blob/main/Project132_135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-f33e4002-c5e3-4a87-b4c1-0ab84b29d5ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f33e4002-c5e3-4a87-b4c1-0ab84b29d5ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('stars.csv')
df.head()
#print(len(df))
# Out:
#    Unnamed: 0       Star_name     Distance  Mass  Radius     Gravity
# 0           0             Sun  0.000015813   1.0    1.00  274.269161
# 1           1          Sirius          8.6   2.1    1.71  196.971800
# 2           2         Canopus          310  15.0   71.00    0.816115
# 3           3  Alpha Centauri          4.4   1.1    1.20  209.511165
# 4           4        Arcturus           37   1.1   26.00    0.446296

# %%
mass= df["Mass"].to_list()
radius= df["Radius"].to_list()
distance= df["Distance"].to_list()
gravity= df["Gravity"].to_list()
star_name = df["Star_name"].to_list()

# %%
import matplotlib.pyplot as plt

mass.sort() 
radius.sort() 
gravity.sort() 
plt.plot(radius,mass)
plt.title("Radius / Mass")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
plt.plot(radius,mass)
plt.title("Radius / Gravity")
plt.xlabel("Radius")
plt.ylabel("Gravity")
plt.show()

# %%
plt.plot(mass,gravity)
plt.title("Mass vs Gravity")
plt.xlabel("Mass")
plt.ylabel("Gravity")
plt.show()

# %%
star_masses = list(mass)
star_radiuses = list(radius)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns 

X = []
for index, star_mass in enumerate(star_masses):
  temp_list = [
      star_radiuses[index],
      star_mass
  ]

  X.append(temp_list)
wcss = []
for i in range(1,11):
  k_means = KMeans(n_clusters = i,init = 'k-means++',random_state = 42)
  k_means.fit(X)
  wcss.append(k_means.inertia_)
  

plt.figure(figsize = (10,5))
sns.lineplot(range(1,11),wcss,marker = 'o',color = 'red')
plt.title("Elbow_method")
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
final_dict = {}
feature_list = []

for d in distance:
  try:
    if d <= 100:
      feature_list.append("distance")    
  except:pass
  for g in gravity:
    try:
      if g > 150 or g < 350:
        feature_list.append("gravity")
    except:pass

final_dict[index] = feature_list
print(final_dict)
# Out:
# {252: ['gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', 'gravity', '
# ...

# %%
star_name_list = list(star_name)
star_mass_list = list(mass)
star_radius_list = list(radius)
star_distance_list = list(distance)
star_gravity_list = list(gravity)

# %%
star_name_list.sort()
star_mass_list.sort() 
star_radius_list.sort() 
star_gravity_list.sort()

# %%
import plotly.express as px

fig  = px.bar(
    df, 
    star_name_list, 
    star_mass_list, 
    color = star_name_list,
    title = "Star Name vs Mass Graph",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig  = px.bar(df, 
    star_name_list, 
    star_radius_list, 
    color = star_name_list,
    title = "Star Name vs Radius Graph", 
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig  = px.bar(
    df, 
    star_name_list, 
    star_distance_list, 
    color = star_name_list,
    title = "Star Name vs Distance Graph",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig  = px.bar(
    df, 
    star_name_list, 
    star_gravity_list, 
    color = star_name_list,
    title = "Star Name vs Gravity Graph")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
